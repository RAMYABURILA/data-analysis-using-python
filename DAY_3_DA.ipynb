# %% [markdown]
# PANDAS:

# %%
import pandas as pd

# %%
l=["ram","sita","rahul","raju"]
r=pd.Series(l,index=[1,2,3,4])
print(r)
l1=[1,2,3,4]
print(pd.Series(l,l1))
# Out:
# 1      ram
# 2     sita
# 3    rahul
# 4     raju
# dtype: object
# 1      ram
# 2     sita
# 3    rahul
# 4     raju
# dtype: object

# %%
#loading csv
dia=pd.read_csv ("/content/diabetcsv (1).csv")
print(dia)
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
grad=pd.read_csv("/content/grades_withnulls.txt")
print(grad)
# Out:
#    Names Initials SEM1 SEM2 SEM3 Grade Placed
# 0                       Joe K 9.8 10 9.9 A+ 1
# 1                   Rajesh M 8.9 9.1 9.3 A 1
# 2                     Kissan V 9.9 9.8 10 A 0
# 3                        Mary N 7.7 8 NaN B 0
# 4                     Jeen K 9.8 9.1 9.9 A+ 1
# 5                       Raj M 8.9 9.1 9.3 A 1
# 6                      Hassan V 9.9 9 9.2 A 1
# 7                        Mari N 7.7 8 7.1 B 1
# 8                     Jess K NaN 9.1 9.9 A+ 1
# 9                    Rajini M NaN 9.1 9.3 A 0
# 10                    Kiran V NaN 9.3 9.2 A 0
# 11                       Maya N 7.7 8 7.1 B 0
# 12                   Jolin K 9.8 9.1 9.9 A+ 1
# 13                   Rajesh M 8.9 9.1 9.3 A 1
# 14                      Riya M 9.3 9.9 10 A 1
# 15                     Sana V 9.9 9.3 9.2 A 0
# 16                         Mark N 7.7 8 7 B 0

# %%
diax1=pd.read_excel("/content/diabetes (6).xlsx")
diax1
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
demo=pd.read_csv("/content/demodt.txt")
print(demo)
# Out:
#    State  Literacy  Cleanliness  Crime_Rate  Good
# 0      A        92           90          54     0
# 1      B        56           67          50     1
# 2      C        78           85          62     0
# 3      D        63           72          48     1
# 4      E        85           79          55     0
# 5      F        71           68          58     0
# 6      G        80           83          51     0
# 7      H        67           74          47     1
# 8      I        89           88          53     0
# 9      J        58           65          49     1
# 10     K        82           81          60     0
# 11     L        75           78          57     0
# 12     M        69           70          46     1
# 13     N        87           86          52     0
# 14     O        61           63          45     1
# 15     P        93           91          56     0
# 16     Q        55           66          61     0
# 17     R        76           77          59     0
# ...

# %%
diaxl1=pd.read_excel("/content/diabetes (6).xlsx",sheet_name="dora")
diaxl1
# Out:
#   Dead Alive
# 0  yes    no
# 1  yes    no
# 2  yes    no
# 3  yes    no
# 4  yes    no

# %%
diaxl.describe()
# Out:
#        Dead Alive
# count     5     5
# unique    1     1
# top     yes    no
# freq      5     5

# %%
demo1.discribe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-777d5984b8e2> in <cell line: 1>()
# ----> 1 demo1.discribe()
#
# NameError: name 'demo1' is not defined

# %%
df=pd.read_csv("/content/grades_withnulls.csv")
print(df)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df=pd.read_csv("/content/grades_withnulls.csv")
print(df)
print(df.shape)
print(df.shape[1])
print(df.shape[0])
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0
# (17, 7)
# 7
# 17

# %%
print(df.isnull())
# Out:
#     Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 0   False     False  False  False  False  False   False
# 1   False     False  False  False  False  False   False
# 2   False     False  False  False  False  False   False
# 3   False     False  False  False   True  False   False
# 4   False     False  False  False  False  False   False
# 5   False     False  False  False  False  False   False
# 6   False     False  False  False  False  False   False
# 7   False     False  False  False  False  False   False
# 8   False     False   True  False  False  False   False
# 9   False     False   True  False  False  False   False
# 10  False     False   True  False  False  False   False
# 11  False     False  False  False  False  False   False
# 12  False     False  False  False  False  False   False
# 13  False     False  False  False  False  False   False
# 14  False     False  False  False  False  False   False
# 15  False     False  False  False  False  False   False
# ...

# %%
print(df.isnull().sum())
# Out:
# Names       0
# Initials    0
# SEM1        3
# SEM2        0
# SEM3        1
# Grade       0
# Placed      0
# dtype: int64

# %%
df.dropna()
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df.dropna(inplace=True)
df
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df=pd.read_csv("/content/grades_withnulls.csv")
mdf=df.dropna()
mdf
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df=pd.read_csv("/content/grades_withnulls.csv")
df.fillna(555,inplace=True)
df
# Out:
#      Names Initials   SEM1  SEM2   SEM3 Grade  Placed
# 0      Joe        K    9.8  10.0    9.9    A+       1
# 1   Rajesh        M    8.9   9.1    9.3     A       1
# 2   Kissan        V    9.9   9.8   10.0     A       0
# 3     Mary        N    7.7   8.0  555.0     B       0
# 4     Jeen        K    9.8   9.1    9.9    A+       1
# 5      Raj        M    8.9   9.1    9.3     A       1
# 6   Hassan        V    9.9   9.0    9.2     A       1
# 7     Mari        N    7.7   8.0    7.1     B       1
# 8     Jess        K  555.0   9.1    9.9    A+       1
# 9   Rajini        M  555.0   9.1    9.3     A       0
# 10   Kiran        V  555.0   9.3    9.2     A       0
# 11    Maya        N    7.7   8.0    7.1     B       0
# 12   Jolin        K    9.8   9.1    9.9    A+       1
# 13  Rajesh        M    8.9   9.1    9.3     A       1
# 14    Riya        M    9.3   9.9   10.0     A       1
# 15    Sana        V    9.9   9.3    9.2     A       0
# ...

# %%
df=pd.read_csv("/content/grades_withnulls.csv")
df.fillna(555)
df
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df=pd.read_csv("/content/grades_withnulls.csv")
mv=df["SEM1"].mean()
print(mv)
df.fillna(mv,inplace=True)
print(df)
# Out:
# 8.992857142857144
#      Names Initials      SEM1  SEM2       SEM3 Grade  Placed
# 0      Joe        K  9.800000  10.0   9.900000    A+       1
# 1   Rajesh        M  8.900000   9.1   9.300000     A       1
# 2   Kissan        V  9.900000   9.8  10.000000     A       0
# 3     Mary        N  7.700000   8.0   8.992857     B       0
# 4     Jeen        K  9.800000   9.1   9.900000    A+       1
# 5      Raj        M  8.900000   9.1   9.300000     A       1
# 6   Hassan        V  9.900000   9.0   9.200000     A       1
# 7     Mari        N  7.700000   8.0   7.100000     B       1
# 8     Jess        K  8.992857   9.1   9.900000    A+       1
# 9   Rajini        M  8.992857   9.1   9.300000     A       0
# 10   Kiran        V  8.992857   9.3   9.200000     A       0
# 11    Maya        N  7.700000   8.0   7.100000     B       0
# 12   Jolin        K  9.800000   9.1   9.900000    A+       1
# 13  Rajesh        M  8.900000   9.1   9.300000     A       1
# ...

# %% [markdown]
# ACCESING THE DATA

# %%
#access the data
#iloc=integer location,index
#loc=field nams,index
#dfname.loc[index--->rows]
#dfname.loc[st:stop]---->range of rows
#dfname,loc[r_ind,col_name]----->row&col
mydf=pd.read_csv("/content/grades_withnulls.csv")
df
mydf.loc[0] #first record
# Out:
# Names        Joe
# Initials       K
# SEM1         9.8
# SEM2        10.0
# SEM3         9.9
# Grade         A+
# Placed         1
# Name: 0, dtype: object

# %%
mydf.loc[8:14]
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1

# %%
mydf.loc[5:7,"SEM1"]  #first records
# Out:
# 5    8.9
# 6    9.9
# 7    7.7
# Name: SEM1, dtype: float64

# %%
mydf.iloc[10:13,0:3]
# Out:
#     Names Initials  SEM1
# 10  Kiran        V   NaN
# 11   Maya        N   7.7
# 12  Jolin        K   9.8

# %%
mydf[mydf.Grade=='A']

# %%
mydf[mydf.SEM2==9.1]
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1

# %%
#print the records whose score is 9.3
mydf[mydf.SEM3==9.3]
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 13  Rajesh        M   8.9   9.1   9.3     A       1

# %%
mydf.loc[mydf['SEM1']>9.8,['Names']]
# Out:
#      Names
# 2   Kissan
# 6   Hassan
# 15    Sana

# %%
#print the grades of students who scored more then 9 in sem1
mydf.loc[mydf['SEM1']>9,['Names']]
# Out:
#      Names
# 0      Joe
# 2   Kissan
# 4     Jeen
# 6   Hassan
# 12   Jolin
# 14    Riya
# 15    Sana

# %%
mydf.loc[mydf.SEM3>9.7,"Grade"]
#accessing the record with sem>9.7 but printing only grade colum
# Out:
# 0     A+
# 2      A
# 4     A+
# 8     A+
# 12    A+
# 14     A
# Name: Grade, dtype: object

# %% [markdown]
# DROPPING THE DUPLICATES:

# %%
mydf.drop_duplicates(inplace=True)
print(mydf)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-ad2f13adb75d> in <cell line: 1>()
# ----> 1 mydf.drop_duplicates(inplace=True)
#       2 print(mydf)
#
# NameError: name 'mydf' is not defined

# %% [markdown]
# NEXT STEPS:

# %%
mydf.tail()               #bottum 5 records
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 11   Maya        N   7.7   8.0   7.1     B       0
# 12  Jolin        K   9.8   9.1   9.9    A+       1
# 14   Riya        M   9.3   9.9  10.0     A       1
# 15   Sana        V   9.9   9.3   9.2     A       0
# 16   Mark        N   7.7   8.0   7.0     B       0

# %%
#accessing using index fun
print(mydf[mydf.index==7])
print("accessing specific  row and colum")
print(mydf.loc[mydf.index==7,"Grade"])
# Out:
#   Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 7  Mari        N   7.7   8.0   7.1     B       1
# accessing specific  row and colum
# 7    B
# Name: Grade, dtype: object

# %%
#colums!
colname=mydf.columns        #view and save column name!
print(colname)
# Out:
# Index(['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'Grade', 'Placed'], dtype='object')

# %%
#colums!
collist=mydf.columns        #view and save column name!
print(collist)
#type casting
# Out:
# Index(['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'Grade', 'Placed'], dtype='object')

# %%
#rename a column!
mydf.rename(columns={'Grade':'GPA'},inplace=True )
mydf.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-df2f76f2c366> in <cell line: 2>()
#       1 #rename a column!
# ----> 2 mydf.rename(columns={'Grade':'GPA'},inplace=True )
#       3 mydf.columns
#
# NameError: name 'mydf' is not defined

# %%
mydf.to_csv("mydf.csv")

# %%
#creatinga new column!
#dfname['new col]=values
mydf["conduct"]="Good"
mydf
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed   average   Average  \
# 0      Joe        K   9.8  10.0   9.9    A+       1  9.900000  9.900000
# 1   Rajesh        M   8.9   9.1   9.3     A       1  9.100000  9.100000
# 2   Kissan        V   9.9   9.8  10.0     A       0  9.900000  9.900000
# 3     Mary        N   7.7   8.0   NaN     B       0       NaN       NaN
# 4     Jeen        K   9.8   9.1   9.9    A+       1  9.600000  9.600000
# 5      Raj        M   8.9   9.1   9.3     A       1  9.100000  9.100000
# 6   Hassan        V   9.9   9.0   9.2     A       1  9.366667  9.366667
# 7     Mari        N   7.7   8.0   7.1     B       1  7.600000  7.600000
# 8     Jess        K   NaN   9.1   9.9    A+       1       NaN       NaN
# 9   Rajini        M   NaN   9.1   9.3     A       0       NaN       NaN
# 10   Kiran        V   NaN   9.3   9.2     A       0       NaN       NaN
# 11    Maya        N   7.7   8.0   7.1     B       0  7.600000  7.600000
# ...

# %%
#crate a new column avg with avg values of sem1 sem2 sem 3

# %%
#creatinga new column!
#dfname['new col]=values
mydf["Average"]=(mydf.SEM1+mydf.SEM2+mydf.SEM3)/3
mydf
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed   average   Average
# 0      Joe        K   9.8  10.0   9.9    A+       1  9.900000  9.900000
# 1   Rajesh        M   8.9   9.1   9.3     A       1  9.100000  9.100000
# 2   Kissan        V   9.9   9.8  10.0     A       0  9.900000  9.900000
# 3     Mary        N   7.7   8.0   NaN     B       0       NaN       NaN
# 4     Jeen        K   9.8   9.1   9.9    A+       1  9.600000  9.600000
# 5      Raj        M   8.9   9.1   9.3     A       1  9.100000  9.100000
# 6   Hassan        V   9.9   9.0   9.2     A       1  9.366667  9.366667
# 7     Mari        N   7.7   8.0   7.1     B       1  7.600000  7.600000
# 8     Jess        K   NaN   9.1   9.9    A+       1       NaN       NaN
# 9   Rajini        M   NaN   9.1   9.3     A       0       NaN       NaN
# 10   Kiran        V   NaN   9.3   9.2     A       0       NaN       NaN
# 11    Maya        N   7.7   8.0   7.1     B       0  7.600000  7.600000
# ...

# %%
import pandas as pd

# %% [markdown]
# plot:

# %%
mydf[['SEM1','SEM2']].plot.line() #plotting mutiple col
# Out:
# <Axes: >

# %%
mydf['SEM1'].plot.line()  #dfname ['col'].plot.line
# Out:
# <Axes: >

# %%
mydf[['SEM1','SEM2']].plot.line(subplots=True)  #all numeric col are plottd!
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
mydf.plot.line()
# Out:
# <Axes: >

# %%
mydf.plot(kind="scatter",x="Average",y="SEM1")
# Out:
# <Axes: xlabel='Average', ylabel='SEM1'>

# %%
mydf.plot(kind="hist",x="Names",y="Average")  #xaxis=numeric
# Out:
# <Axes: ylabel='Frequency'>

# %%
mydf.to_csv("mydf.csv")
#dfname.to_csv("filename.csv")
