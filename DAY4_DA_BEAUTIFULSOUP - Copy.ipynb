# %% [markdown]
#  nnnhnb Extracting HTML code of a webpage

# %%
# Out:
#   File "<ipython-input-41-2d7934bfca54>", line 1
#     1)import libraries
#      ^
# SyntaxError: unmatched ')'

# %%
from bs4 import BeautifulSoup

# %%
import requests as rq

# %%
var="https://www.google.com/search?q=google&oq=google+&gs_lcrp=EgZjaHJvbWUyBggAEEUYOTIMCAEQIxgnGIAEGIoFMg4IAhBFGCcYOxiABBiKBTINCAMQABiDARixAxiABDINCAQQABiDARixAxiABDINCAUQABiDARixAxiABDINCAYQABiDARixAxiABDINCAcQABiDARixAxiABDIHCAgQABiPAjIHCAkQABiPAtIBCTgwMzFqMGoxNagCALACAA&sourceid=chrome&ie=UTF-8"
page=rq.get(var)

# %%
code=BeautifulSoup(page.text,'html')
code
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><meta charset="utf-8"/><meta content="AjoCq8Zg5PcXgfl/SoTikc1e/dzQCdxW0fvo8FxmdXtMpTHFSPThDszr2GTn4aDO9n/lpkW3Zv/js+E6AktuqgkAAABveyJvcmlnaW4iOiJodHRwczovL2dvb2dsZS5jb206NDQzIiwiZmVhdHVyZSI6IkxvbmdBbmltYXRpb25GcmFtZVRpbWluZyIsImV4cGlyeSI6MTcwOTY4MzE5OSwiaXNTdWJkb21haW4iOnRydWV9" http-equiv="origin-trial"/><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/><title>google - Google Search</title><script nonce="imiH_xXROo2ilvRBzkKKTA">(function(){
# ...

# %%
find=("title")

# %%
r=code.find("title")
print(r)
# Out:
# <title>google - Google Search</title>

# %%
#remove af tag
print(r.text)
# Out:
# google - Google Search

# %% [markdown]
# extracting table from webpage

# %%
import bs4 as BeautifulSoup

# %%
import requests as rq

# %%
s="https://www.forbesindia.com/article/explainers/top-10-richest-people-india/85909/1"
page1=rq.get(s)

# %%
c=BeautifulSoup(page1.text,'html')
c
# Out:
# <!-- Top header Advertisment --><!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>Top 10 Richest People In India In 2024 | Who Is The Richest Man And Woman In India - Forbes India</title>
# <meta content="Gain insights into the extraordinary wealth and remarkable achievements of the ten wealthiest individuals in India, spanning various industries" name="description"/>
# <link href="https://www.forbesindia.com/images/forbesicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://www.forbesindia.com/media/images/2023/Jun/img_210953_top10.jpg" rel="image_src"/>
# <link href="https://www.forbesindia.com/article/explainers/top-10-richest-people-india/85909/1" rel="canonical"/>
# <link href="https://www.forbesindia.com/amp/article/explainers/top-10-richest-people-india/85909/1" rel="amphtml"/>
# <!-- for Facebook -->
# ...

# %%
code1=BeautifulSoup(c.text,'html')
code1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0da62f3eb969> in <cell line: 1>()
# ----> 1 code1=BeautifulSoup(c.text,'html')
#       2 code1
#
# NameError: name 'BeautifulSoup' is not defined

# %%
tb=c.find("table")
tb
# Out:
# <table style="border-collapse: collapse;">
# <tbody>
# <tr>
# <th style="border: 1px solid black; padding: 8px;"><strong>Name &amp; India Rank</strong></th>
# <th style="border: 1px solid black; padding: 8px;"><strong>Global Rank</strong></th>
# <th style="border: 1px solid black; padding: 8px;"><strong>Net worth (US$)</strong></th>
# <th style="border: 1px solid black; padding: 8px;"><strong>Company</strong></th>
# </tr>
# <tr>
# <td style="border: 1px solid black; padding: 8px;">#1 Mukesh Ambani <br/></td>
# <td style="border: 1px solid black; padding: 8px;">10</td>
# <td style="border: 1px solid black; padding: 8px;">$116.9 B</td>
# <td style="border: 1px solid black; padding: 8px;">Reliance Industries</td>
# </tr>
# <tr>
# <td style="border: 1px solid black; padding: 8px;">#2 Gautam Adani <br/></td>
# <td style="border: 1px solid black; padding: 8px;">16<br/></td>
# <td style="border: 1px solid black; padding: 8px;">$86.2 B</td>
# ...

# %%
h=c.find_all('th')
print(h)
# Out:
# [<th style="border: 1px solid black; padding: 8px;"><strong>Name &amp; India Rank</strong></th>, <th style="border: 1px solid black; padding: 8px;"><strong>Global Rank</strong></th>, <th style="border: 1px solid black; padding: 8px;"><strong>Net worth (US$)</strong></th>, <th style="border: 1px solid black; padding: 8px;"><strong>Company</strong></th>]

# %%
#creat a list
heading=[i.text for i in h]
heading
# Out:
# ['Name & India Rank', 'Global Rank', 'Net worth (US$)', 'Company']

# %%
import pandas as pd

# %%
mydf=pd.DataFrame(columns=heading)
print(mydf)
# Out:
# Empty DataFrame
# Columns: [Name & India Rank, Global Rank, Net worth (US$), Company]
# Index: []

# %%
rows=c.find_all('td')
y=[i.text for i in rows]
print(y)
# Out:
# ['#1 Mukesh Ambani ', '10', '$116.9 B', 'Reliance Industries', '#2 Gautam Adani ', '16', '$86.2 B', 'Adani Group', '#3 Shiv Nadar ', '37', '$36.8 B', 'HCL Technologies\xa0\xa0 ', '#4 Savitri Jindal & family ', '58', '$30.9 B', 'JSW Group', '#5 Dilip Shanghvi ', '69', '$25.7 B', 'Sun Pharmaceutical Industries Ltd', '#6 Cyrus Poonawalla ', '68', '$24.2 B', 'Serum Institute of India', '#7 Kushal Pal Singh', '98', '$20.6 B', 'DLF Limited', '#8 Kumar Birla ', '97', '$19.5 B', 'Aditya Birla Group', '#9 Ravi Jaipuria', '100', '$17.4 B', 'RJ Corp, Varun Beverages ', '#10 Radhakishan Damani ', '101', '$17.2 B', 'DMart, Avenue Supermarts']

# %%
data[0:4]
# Out:
# ['\nName & India Rank\nGlobal Rank\nNet worth (US$)\nCompany\n',
#  '\n#1 Mukesh Ambani \n10\n$116.9 B\nReliance Industries\n',
#  '\n#2 Gautam Adani \n16\n$86.2 B\nAdani Group\n',
#  '\n#3 Shiv Nadar \n37\n$36.8 B\nHCL Technologies\xa0\xa0 \n']

# %%
data[0:8]
# Out:
# ['\nName & India Rank\nGlobal Rank\nNet worth (US$)\nCompany\n',
#  '\n#1 Mukesh Ambani \n10\n$116.9 B\nReliance Industries\n',
#  '\n#2 Gautam Adani \n16\n$86.2 B\nAdani Group\n',
#  '\n#3 Shiv Nadar \n37\n$36.8 B\nHCL Technologies\xa0\xa0 \n',
#  '\n#4 Savitri Jindal & family \n58\n$30.9 B\nJSW Group\n',
#  '\n#5 Dilip Shanghvi \n69\n$25.7 B\nSun Pharmaceutical Industries Ltd\n',
#  '\n#6 Cyrus Poonawalla \n68\n$24.2 B\nSerum Institute of India\n',
#  '\n#7 Kushal Pal Singh\n98\n$20.6 B\nDLF Limited\n']

# %%
ind=0
st = 0

for i in range(10):

  mydf.loc[ind]=y[st:st+4]
  ind=ind+4
  st=st+4
print(mydf)
# Out:
#               Name & India Rank Global Rank Net worth (US$)  \
# 0             #1 Mukesh Ambani           10        $116.9 B
# 4              #2 Gautam Adani           16         $86.2 B
# 8                #3 Shiv Nadar           37         $36.8 B
# 12  #4 Savitri Jindal & family           58         $30.9 B
# 16           #5 Dilip Shanghvi           69         $25.7 B
# 20         #6 Cyrus Poonawalla           68         $24.2 B
# 24          #7 Kushal Pal Singh          98         $20.6 B
# 28              #8 Kumar Birla           97         $19.5 B
# 32             #9 Ravi Jaipuria         100         $17.4 B
# 36      #10 Radhakishan Damani          101         $17.2 B
#
#                               Company
# 0                 Reliance Industries
# 4                         Adani Group
# 8                 HCL Technologies
# 12                          JSW Group
# 16  Sun Pharmaceutical Industries Ltd
# 20           Serum Institute of India
# ...

# %%
mydf
# Out:
#               Name & India Rank Global Rank Net worth (US$)  \
# 0             #1 Mukesh Ambani           10        $116.9 B
# 4              #2 Gautam Adani           16         $86.2 B
# 8                #3 Shiv Nadar           37         $36.8 B
# 12  #4 Savitri Jindal & family           58         $30.9 B
# 16           #5 Dilip Shanghvi           69         $25.7 B
# 20         #6 Cyrus Poonawalla           68         $24.2 B
# 24          #7 Kushal Pal Singh          98         $20.6 B
# 28              #8 Kumar Birla           97         $19.5 B
# 32             #9 Ravi Jaipuria         100         $17.4 B
# 36      #10 Radhakishan Damani          101         $17.2 B
#
#                               Company
# 0                 Reliance Industries
# 4                         Adani Group
# 8                 HCL Technologies
# 12                          JSW Group
# 16  Sun Pharmaceutical Industries Ltd
# 20           Serum Institute of India
# ...

# %%
mydf.csv("mydf.csv")

# %%
from  bs4  import BeautifulSoup
import requests as rq

# %%
url1="https://en.m.wikipedia.org/wiki/List_of_tallest_buildings_in_India"
page=rq.get(url1)
code1=BeautifulSoup(page.text,'html')
code1
# Out:
# <!DOCTYPE html>
# <html class="client-nojs mf-expand-sections-clientpref-0 mf-font-size-clientpref-small mw-mf-amc-clientpref-0 T357724" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of tallest buildings in India - Wikipedia</title>
# ...

# %%
t=code1.find('table')
t
# Out:
# <table class="wikitable sortable"><tbody><tr style="background:#ececec;"><th>Rank
# </th>
# <th>Name
# </th>
# <th>Image
# </th>
# <th>City
# </th>
# <th>Height
# </th>
# <th>Floors
# </th>
# <th>Year
# </th>
# <th>Building type
# </th>
# <th>Reference(s)
# </th></tr><tr><td>1
# </td>
# <td><a href="/wiki/Palais_Royale,_Mumbai" title="Palais Royale, Mumbai">Palais Royale</a>
# </td>
# ...

# %%
t1=t.find_all('th')
t1
# Out:
# [<th>Rank
#  </th>,
#  <th>Name
#  </th>,
#  <th>Image
#  </th>,
#  <th>City
#  </th>,
#  <th>Height
#  </th>,
#  <th>Floors
#  </th>,
#  <th>Year
#  </th>,
#  <th>Building type
#  </th>,
#  <th>Reference(s)
#  </th>]

# %%
heading=[i.text for i in t1]
heading
# Out:
# ['Rank\n',
#  'Name\n',
#  'Image\n',
#  'City\n',
#  'Height\n',
#  'Floors\n',
#  'Year\n',
#  'Building type\n',
#  'Reference(s)\n']

# %%
import pandas as pd

# %%
mydf=pd.DataFrame(columns=heading)
print(mydf)
# Out:
# Empty DataFrame
# Columns: [Rank
# , Name
# , Image
# , City
# , Height
# , Floors
# , Year
# , Building type
# , Reference(s)
# ]
# Index: []

# %%
rows=t.find_all('tr')
rows
# Out:
# [<tr style="background:#ececec;"><th>Rank
#  </th>
#  <th>Name
#  </th>
#  <th>Image
#  </th>
#  <th>City
#  </th>
#  <th>Height
#  </th>
#  <th>Floors
#  </th>
#  <th>Year
#  </th>
#  <th>Building type
#  </th>
#  <th>Reference(s)
#  </th></tr>,
#  <tr><td>1
#  </td>
#  <td><a href="/wiki/Palais_Royale,_Mumbai" title="Palais Royale, Mumbai">Palais Royale</a>
#  </td>
# ...

# %%
data=t.find_all('td')
data
# Out:
# [<td>1
#  </td>,
#  <td><a href="/wiki/Palais_Royale,_Mumbai" title="Palais Royale, Mumbai">Palais Royale</a>
#  </td>,
# ...

# %%
data=[i.text for i in data]
data
# Out:
# ['1\n',
#  'Palais Royale\n',
#  '\xa0\n',
#  'Mumbai\n',
#  '320 metres (1,050\xa0ft)\n',
#  '88\n',
#  '2018\n',
#  'Residential\n',
#  '[22]',
#  '2\n',
#  'Lokhandwala Minerva\n',
#  '\xa0\n',
#  'Mumbai\n',
#  '301 metres (988\xa0ft)\n',
#  '78\n',
#  '2023\n',
#  'Residential\n',
#  '[23][24]',
#  '3\n',
#  'Piramal Aranya Arav\n',
#  '\n',
#  'Mumbai\n',
#  '282.2 metres (926\xa0ft)\n',
#  '83\n',
#  '2022\n',
#  'Residential\n',
#  '[25]',
#  '4\n',
#  'World One\n',
#  '\xa0\n',
#  'Mumbai\n',
#  '280.2 metres (919\xa0ft)\n',
#  '76\n',
#  '2020\n',
#  'Residential\n',
#  '[4][26]',
#  '5\n',
#  'World View\n',
#  '\xa0\n',
#  'Mumbai\n',
#  '277.6 metres (911\xa0ft)\n',
#  '73\n',
#  '2020\n',
#  'Residential\n',
#  '[27][28]',
#  '6\n',
#  'Lodha Trump Tower\n',
#  '\xa0\n',
#  'Mumbai\n',
#  '268 metres (879\xa0ft)\n',
#  '76\n',
#  '2020\n',
#  'Residential\n',
#  '[29][30][31]',
#  'Lodha Marquise\n',
#  '\xa0\n',
#  'Lodha Allura\n',
#  '\xa0\n',
# ...

# %%
df=pd.DataFrame(columns=['rank','name','image','city','height','floors','year','bd','reference'])
df
# Out:
# Empty DataFrame
# Columns: [rank, name, image, city, height, floors, year, bd, reference]
# Index: []

# %%
data[0:9]
# Out:
# ['1\n',
#  'Palais Royale\n',
#  '\xa0\n',
#  'Mumbai\n',
#  '320 metres (1,050\xa0ft)\n',
#  '88\n',
#  '2018\n',
#  'Residential\n',
#  '[22]']

# %%
print(len(data))
# Out:
# 563

# %%
index=0
start=0
stop=9
for i in range(len(data)//9):
    mydf.loc[index]=data[start:stop]
    start=start+9
    stop=stop+9
    index=index+1
mydf.head(10)
# Out:
#                  Rank\n                 Name\n                     Image\n  \
# 0                   1\n        Palais Royale\n                          \n
# 1                   2\n  Lokhandwala Minerva\n                          \n
# 2                   3\n  Piramal Aranya Arav\n                          \n
# 3                   4\n            World One\n                          \n
# 4                   5\n           World View\n                          \n
# 5                   6\n    Lodha Trump Tower\n                          \n
# 6      Lodha Marquise\n                     \n              Lodha Allura\n
# 7  Omkar 1973 Tower A\n                     \n                    Mumbai\n
# 8                    \n                   13\n           Nathani Heights\n
# 9              [34][35]                   14\n  Three Sixty West Tower B\n
#
#                   City\n                 Height\n               Floors\n  \
# ...
